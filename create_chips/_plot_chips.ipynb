# %%
import numpy
import matplotlib.pyplot as plt

# %%
chips = numpy.load('../../chips/32_nw.npy')

# %%
fig, ax = plt.subplots(figsize=(20,20))
plt.imshow(chips[7237])

# %%
fig, ax = plt.subplots(figsize=(12.5,12.5))
plt.imshow(chips[7237][:25, :25, :])
