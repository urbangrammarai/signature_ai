# %%
import numpy
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.applications import resnet_v2, vgg16, efficientnet

from model_builder import model_builder, relabel, class_merger, balancer

import model_builder
import tools_keras

from itertools import product

# %% [markdown]
# Load chips

# %%
specs = {
    'tensor': (
        '../urbangrammar_samba/'
        'spatial_signatures/chips/sample.npz'
    ),
    'folder': "../urbangrammar_samba/spatial_signatures/ai/nw_32/",
}

# %%
data = numpy.load(specs["tensor"], allow_pickle=True)

# %%
chips = data["chips"]
labels = data["labels"]

# %% [markdown]
# Shuffle data to ensure full randomness before splitting to test, validation and secret.

# %%
numpy.random.seed(0)

shuffled_idx = numpy.arange(0, chips.shape[0])
numpy.random.shuffle(shuffled_idx)

chips = chips[shuffled_idx]
labels = labels[shuffled_idx]

# %% [markdown]
# Merge groups

# %%
group_mapping = [
    ['9_0', '9_1', '9_2', '9_4', '9_5', '2_0', '2_1', '2_2'],
    ['1_0', '3_0', '5_0', '6_0', '8_0'],
    ['0_0', '4_0', '7_0']
]
labels = class_merger(labels, group_mapping)

# If you don't want to merge groups, use `relabel` to ensure your labels are in the proper format
# labels = relabel(labels)

# %% [markdown]
# Drop chips from excessive classes

# %%
mask = balancer(labels, max_ratio=10)
# Out:
# Total number of selected chips: 18841 out of 65042
# Counts:
#  {0: 907, 1: 8864, 2: 9070}

# %%
labels = labels[mask]
chips = chips[mask]

# %% [markdown]
# Rescale

# %%
chips = chips / (chips.max() / 255.0)

# %% [markdown]
# Split data into train and validation.

# %%
batch_size = 32
split_1 = int(chips.shape[0] * 0.6)
split_2 = int(chips.shape[0] * 0.8)


# assert that all labels are present in train and validation datasets
assert (numpy.unique(labels[:split_1]) == numpy.unique(labels[split_1:split_2])).all()
assert (numpy.unique(labels[:split_1]) == numpy.unique(labels[split_2:])).all()


train_dataset = tf.data.Dataset.from_tensor_slices((chips[:split_1], labels[:split_1]))
validation_dataset = tf.data.Dataset.from_tensor_slices((chips[split_1:split_2], labels[split_1:split_2]))
secret_dataset = tf.data.Dataset.from_tensor_slices((chips[split_2:], labels[split_2:]))


train_dataset = train_dataset.batch(batch_size=batch_size)
validation_dataset = validation_dataset.batch(batch_size=batch_size)
secret_dataset = secret_dataset.batch(batch_size=batch_size)

# %%
model_specs = {
    'meta_class_map': group_mapping,
    'meta_class_names': ["centres", "periphery", "countryside"],
    'meta_chip_size': 32,
}

inputs = keras.Input(shape=(32, 32, 3))
x = layers.Resizing(224, 224, crop_to_aspect_ratio=True)(inputs)
x = vgg16.preprocess_input(x)
m = keras.applications.VGG16(
    include_top=True,
    weights=None,
    input_tensor=None,
    input_shape=(224, 224, 3),
    pooling="avg",
    classes=3,
    classifier_activation="softmax")(x)
model = keras.Model(
            inputs,
            m,
            name=f"vgg16_none_none_3"
    )
# compile
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)

# %%
h = tools_keras.fit_phase(
        model,
        train_dataset,
        validation_dataset,
        secret_dataset,
        log_folder=specs["folder"] + "logs",
        pred_folder=specs["folder"] + "pred",
        model_folder=specs["folder"] + "model",
        json_folder=specs["folder"] + "json",
        specs=model_specs,
        epochs=250,
        patience=50,
        verbose=True,

    )
# Out:
# Model: "vgg16_none_none_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_25 (InputLayer)        [(None, 32, 32, 3)]       0
# _________________________________________________________________
# resizing_3 (Resizing)        (None, 224, 224, 3)       0
# _________________________________________________________________
# tf.__operators__.getitem (Sl (None, 224, 224, 3)       0
# _________________________________________________________________
# tf.nn.bias_add (TFOpLambda)  (None, 224, 224, 3)       0
# _________________________________________________________________
# vgg16 (Functional)           (None, 3)                 134272835
# =================================================================
# Total params: 134,272,835
# Trainable params: 134,272,835
# Non-trainable params: 0
# _________________________________________________________________
# None
# 2022-01-17 18:22:32.331301: I tensorflow/core/profiler/lib/profiler_session.cc:131] Profiler session initializing.
# 2022-01-17 18:22:32.331369: I tensorflow/core/profiler/lib/profiler_session.cc:146] Profiler session started.
# 2022-01-17 18:22:32.512681: I tensorflow/core/profiler/lib/profiler_session.cc:164] Profiler session tear down.
# 2022-01-17 18:22:32.512838: I tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1749] CUPTI activity buffer flushed
# Epoch 1/250
# 2022-01-17 18:22:43.466694: W tensorflow/core/common_runtime/bfc_allocator.cc:463] Allocator (GPU_0_bfc) ran out of memory trying to allocate 392.00MiB (rounded to 411041792)requested by op gradient_tape/vgg16_none_none_3/vgg16/fc1/MatMul_1
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2022-01-17 18:22:43.466821: I tensorflow/core/common_runtime/bfc_allocator.cc:1013] BFCAllocator dump for GPU_0_bfc
# 2022-01-17 18:22:43.466875: I tensorflow/core/common_runtime/bfc_allocator.cc:1020] Bin (256): 	Total Chunks: 346, Chunks in use: 345. 86.5KiB allocated for chunks. 86.2KiB in use in bin. 5.4KiB client-requested in use in bin.
# 2022-01-17 18:22:43.466896: I tensorflow/core/common_runtime/bfc_allocator.cc:1020] Bin (512): 	Total Chunks: 16, Chunks in use: 16. 8.2KiB allocated for chunks. 8.2KiB in use in bin. 8.0KiB client-requested in use in bin.
# 2022-01-17 18:22:43.467017: I tensorflow/core/common_runtime/bfc_allocator.cc:1020] Bin (1024): 	Total Chunks: 28, Chunks in use: 27. 28.5KiB allocated for chunks. 27.2KiB in use in bin. 27.0KiB client-requested in use in bin.
# 2022-01-17 18:22:43.467101: I tensorflow/core/common_runtime/bfc_allocator.cc:1020] Bin (2048): 	Total Chunks: 52, Chunks in use: 52. 106.8KiB allocated for chunks. 106.8KiB in use in bin. 104.0KiB client-requested in use in bin.
# 2022-01-17 18:22:43.467129: I tensorflow/core/common_runtime/bfc_allocator.cc:1020] Bin (4096): 	Total Chunks: 8, Chunks in use: 8. 54.2KiB allocated for chunks. 54.2KiB in use in bin. 53.2KiB client-requested in use in bin.
# 2022-01-17 18:22:43.467155: I tensorflow/core/common_runtime/bfc_allocator.cc:1020] Bin (8192): 	Total Chunks: 1, Chunks in use: 1. 10.2KiB allocated for chunks. 10.2KiB in use in bin. 6.8KiB client-requested in use in bin.
# 2022-01-17 18:22:43.467177: I tensorflow/core/common_runtime/bfc_allocator.cc:1020] Bin (16384): 	Total Chunks: 13, Chunks in use: 13. 247.0KiB allocated for chunks. 247.0KiB in use in bin. 221.4KiB client-requested in use in bin.
# 2022-01-17 18:22:43.467194: I tensorflow/core/common_runtime/bfc_allocator.cc:1020] Bin (32768): 	Total Chunks: 6, Chunks in use: 6. 264.8KiB allocated for chunks. 264.8KiB in use in bin. 232.3KiB client-requested in use in bin.
# 2022-01-17 18:22:43.467210: I tensorflow/core/common_runtime/bfc_allocator.cc:1020] Bin (65536): 	Total Chunks: 5, Chunks in use: 5. 412.8KiB allocated for chunks. 412.8KiB in use in bin. 320.6KiB client-requested in use in bin.
# 2022-01-17 18:22:43.467225: I tensorflow/core/common_runtime/bfc_allocator.cc:1020] Bin (131072): 	Total Chunks: 9, Chunks in use: 8. 1.47MiB allocated for chunks. 1.24MiB in use in bin. 1.12MiB client-requested in use in bin.
# 2022-01-17 18:22:43.467240: I tensorflow/core/common_runtime/bfc_allocator.cc:1020] Bin (262144): 	Total Chunks: 10, Chunks in use: 8. 2.98MiB allocated for chunks. 2.44MiB in use in bin. 2.25MiB client-requested in use in bin.
# 2022-01-17 18:22:43.467254: I tensorflow/core/common_runtime/bfc_allocator.cc:1020] Bin (524288): 	Total Chunks: 11, Chunks in use: 9. 6.29MiB allocated for chunks. 5.10MiB in use in bin. 5.00MiB client-requested in use in bin.
# 2022-01-17 18:22:43.467269: I tensorflow/core/common_runtime/bfc_allocator.cc:1020] Bin (1048576): 	Total Chunks: 8, Chunks in use: 8. 9.70MiB allocated for chunks. 9.70MiB in use in bin. 9.00MiB client-requested in use in bin.
# 2022-01-17 18:22:43.467285: I tensorflow/core/common_runtime/bfc_allocator.cc:1020] Bin (2097152): 	Total Chunks: 19, Chunks in use: 19. 44.94MiB allocated for chunks. 44.94MiB in use in bin. 44.38MiB client-requested in use in bin.
# 2022-01-17 18:22:43.467301: I tensorflow/core/common_runtime/bfc_allocator.cc:1020] Bin (4194304): 	Total Chunks: 8, Chunks in use: 8. 35.75MiB allocated for chunks. 35.75MiB in use in bin. 33.75MiB client-requested in use in bin.
# 2022-01-17 18:22:43.467318: I tensorflow/core/common_runtime/bfc_allocator.cc:1020] Bin (8388608): 	Total Chunks: 48, Chunks in use: 48. 467.97MiB allocated for chunks. 467.97MiB in use in bin. 437.25MiB client-requested in use in bin.
# 2022-01-17 18:22:43.467334: I tensorflow/core/common_runtime/bfc_allocator.cc:1020] Bin (16777216): 	Total Chunks: 3, Chunks in use: 3. 62.72MiB allocated for chunks. 62.72MiB in use in bin. 55.12MiB client-requested in use in bin.
# 2022-01-17 18:22:43.467350: I tensorflow/core/common_runtime/bfc_allocator.cc:1020] Bin (33554432): 	Total Chunks: 1, Chunks in use: 1. 57.50MiB allocated for chunks. 57.50MiB in use in bin. 49.00MiB client-requested in use in bin.
# 2022-01-17 18:22:43.467370: I tensorflow/core/common_runtime/bfc_allocator.cc:1020] Bin (67108864): 	Total Chunks: 16, Chunks in use: 15. 1.26GiB allocated for chunks. 1.19GiB in use in bin. 1.06GiB client-requested in use in bin.
# 2022-01-17 18:22:43.467388: I tensorflow/core/common_runtime/bfc_allocator.cc:1020] Bin (134217728): 	Total Chunks: 5, Chunks in use: 4. 932.18MiB allocated for chunks. 694.25MiB in use in bin. 578.31MiB client-requested in use in bin.
# 2022-01-17 18:22:43.467402: I tensorflow/core/common_runtime/bfc_allocator.cc:1020] Bin (268435456): 	Total Chunks: 10, Chunks in use: 10. 3.58GiB allocated for chunks. 3.58GiB in use in bin. 3.58GiB client-requested in use in bin.
# 2022-01-17 18:22:43.467418: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] Bin for 392.00MiB was 256.00MiB, Chunk State:
# 2022-01-17 18:22:43.467431: I tensorflow/core/common_runtime/bfc_allocator.cc:1049] Next region of size 6896943104
# 2022-01-17 18:22:43.467449: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7fd512000000 of size 277807104 next 1
# 2022-01-17 18:22:43.467461: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7fd5228f0000 of size 1280 next 2
# 2022-01-17 18:22:43.467473: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7fd5228f0500 of size 92626944 next 3
# 2022-01-17 18:22:43.467485: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7fd528146500 of size 12845056 next 283
# 2022-01-17 18:22:43.467497: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7fd528d86500 of size 3211264 next 316
# 2022-01-17 18:22:43.467509: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7fd529096500 of size 3211264 next 118
# 2022-01-17 18:22:43.467521: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] Free  at 7fd5293a6500 of size 73485824 next 7
# 2022-01-17 18:22:43.467533: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7fd52d9bb300 of size 256 next 8
# 2022-01-17 18:22:43.467544: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7fd52d9bb400 of size 256 next 9
# 2022-01-17 18:22:43.467555: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7fd52d9bb500 of size 256 next 10
# 2022-01-17 18:22:43.467566: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7fd52d9bb600 of size 256 next 11
# 2022-01-17 18:22:43.467577: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7fd52d9bb700 of size 256 next 12
# 2022-01-17 18:22:43.467588: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7fd52d9bb800 of size 256 next 13
# 2022-01-17 18:22:43.467600: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7fd52d9bb900 of size 256 next 16
# 2022-01-17 18:22:43.467611: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7fd52d9bba00 of size 256 next 17
# 2022-01-17 18:22:43.467622: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7fd52d9bbb00 of size 256 next 18
# 2022-01-17 18:22:43.467633: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7fd52d9bbc00 of size 256 next 21
# 2022-01-17 18:22:43.467644: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7fd52d9bbd00 of size 256 next 22
# 2022-01-17 18:22:43.467656: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7fd52d9bbe00 of size 512 next 25
# 2022-01-17 18:22:43.467667: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7fd52d9bc000 of size 256 next 26
# 2022-01-17 18:22:43.467679: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7fd52d9bc100 of size 256 next 27
# 2022-01-17 18:22:43.467690: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7fd52d9bc200 of size 512 next 28
# 2022-01-17 18:22:43.467702: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7fd52d9bc400 of size 256 next 31
# 2022-01-17 18:22:43.467720: I tensorflow/core/common_runtime/bfc_allocator.cc:1069] InUse at 7
# 2022-01-17 18:22:53.490626: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 1 Chunks of size 1280 totalling 1.2KiB
# 2022-01-17 18:22:53.490647: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 48 Chunks of size 2048 totalling 96.0KiB
# 2022-01-17 18:22:53.490662: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 3 Chunks of size 2560 totalling 7.5KiB
# 2022-01-17 18:22:53.490676: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 1 Chunks of size 3328 totalling 3.2KiB
# 2022-01-17 18:22:53.490689: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 1 Chunks of size 6144 totalling 6.0KiB
# 2022-01-17 18:22:53.490704: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 6 Chunks of size 6912 totalling 40.5KiB
# 2022-01-17 18:22:53.490717: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 1 Chunks of size 7936 totalling 7.8KiB
# 2022-01-17 18:22:53.490732: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 1 Chunks of size 10496 totalling 10.2KiB
# 2022-01-17 18:22:53.490746: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 9 Chunks of size 16384 totalling 144.0KiB
# 2022-01-17 18:22:53.490761: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 1 Chunks of size 23808 totalling 23.2KiB
# 2022-01-17 18:22:53.490775: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 1 Chunks of size 25088 totalling 24.5KiB
# 2022-01-17 18:22:53.490789: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 1 Chunks of size 26368 totalling 25.8KiB
# 2022-01-17 18:22:53.490803: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 1 Chunks of size 30208 totalling 29.5KiB
# 2022-01-17 18:22:53.490817: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 1 Chunks of size 34048 totalling 33.2KiB
# 2022-01-17 18:22:53.490831: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 1 Chunks of size 40448 totalling 39.5KiB
# 2022-01-17 18:22:53.490859: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 4 Chunks of size 49152 totalling 192.0KiB
# 2022-01-17 18:22:53.490877: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 1 Chunks of size 65536 totalling 64.0KiB
# 2022-01-17 18:22:53.490892: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 1 Chunks of size 65792 totalling 64.2KiB
# 2022-01-17 18:22:53.490906: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 1 Chunks of size 94720 totalling 92.5KiB
# 2022-01-17 18:22:53.490920: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 2 Chunks of size 98304 totalling 192.0KiB
# 2022-01-17 18:22:53.490934: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 4 Chunks of size 147456 totalling 576.0KiB
# 2022-01-17 18:22:53.490948: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 1 Chunks of size 155904 totalling 152.2KiB
# 2022-01-17 18:22:53.490963: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 1 Chunks of size 171008 totalling 167.0KiB
# 2022-01-17 18:22:53.490977: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 1 Chunks of size 191488 totalling 187.0KiB
# 2022-01-17 18:22:53.490992: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 1 Chunks of size 196864 totalling 192.2KiB
# 2022-01-17 18:22:53.491005: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 1 Chunks of size 241408 totalling 235.8KiB
# 2022-01-17 18:22:53.491020: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 6 Chunks of size 294912 totalling 1.69MiB
# 2022-01-17 18:22:53.491034: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 1 Chunks of size 344320 totalling 336.2KiB
# 2022-01-17 18:22:53.491047: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 1 Chunks of size 442368 totalling 432.0KiB
# 2022-01-17 18:22:53.491061: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 7 Chunks of size 589824 totalling 3.94MiB
# 2022-01-17 18:22:53.491075: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 1 Chunks of size 695040 totalling 678.8KiB
# 2022-01-17 18:22:53.491089: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 6 Chunks of size 1179648 totalling 6.75MiB
# 2022-01-17 18:22:53.491103: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 1 Chunks of size 1327104 totalling 1.27MiB
# 2022-01-17 18:22:53.491117: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 1 Chunks of size 1769472 totalling 1.69MiB
# 2022-01-17 18:22:53.491131: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 16 Chunks of size 2359296 totalling 36.00MiB
# 2022-01-17 18:22:53.491144: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 1 Chunks of size 2949120 totalling 2.81MiB
# 2022-01-17 18:22:53.491158: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 1 Chunks of size 4456448 totalling 4.25MiB
# 2022-01-17 18:22:53.491172: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 7 Chunks of size 4718592 totalling 31.50MiB
# 2022-01-17 18:22:53.491187: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 1 Chunks of size 9142272 totalling 8.72MiB
# 2022-01-17 18:22:53.491201: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 36 Chunks of size 9437184 totalling 324.00MiB
# 2022-01-17 18:22:53.491215: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 3 Chunks of size 10485760 totalling 30.00MiB
# 2022-01-17 18:22:53.491229: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 1 Chunks of size 11796480 totalling 11.25MiB
# 2022-01-17 18:22:53.491244: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 2 Chunks of size 14155776 totalling 27.00MiB
# 2022-01-17 18:22:53.491259: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 1 Chunks of size 15204352 totalling 14.50MiB
# 2022-01-17 18:22:53.491273: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 1 Chunks of size 16515072 totalling 15.75MiB
# 2022-01-17 18:22:53.491287: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 1 Chunks of size 22544384 totalling 21.50MiB
# 2022-01-17 18:22:53.491302: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 4 Chunks of size 67108864 totalling 256.00MiB
# 2022-01-17 18:22:53.491316: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 1 Chunks of size 75497472 totalling 72.00MiB
# 2022-01-17 18:22:53.491329: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 1 Chunks of size 92602368 totalling 88.31MiB
# 2022-01-17 18:22:53.491344: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 2 Chunks of size 92626944 totalling 176.67MiB
# 2022-01-17 18:22:53.491358: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 1 Chunks of size 115343360 totalling 110.00MiB
# 2022-01-17 18:22:53.491373: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 1 Chunks of size 153092096 totalling 146.00MiB
# 2022-01-17 18:22:53.491388: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 2 Chunks of size 277807104 totalling 529.88MiB
# 2022-01-17 18:22:53.491401: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 7 Chunks of size 411041792 totalling 2.68GiB
# 2022-01-17 18:22:53.491416: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 1 Chunks of size 455005952 totalling 433.93MiB
# 2022-01-17 18:22:53.491430: I tensorflow/core/common_runtime/bfc_allocator.cc:1077] 1 Chunks of size 513802240 totalling 490.00MiB
# 2022-01-17 18:22:53.491444: I tensorflow/core/common_runtime/bfc_allocator.cc:1081] Sum Total of in-use chunks: 5.46GiB
# 2022-01-17 18:22:53.491457: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] total_region_allocated_bytes_: 6896943104 memory_limit_: 6896943104 available bytes: 0 curr_region_allocation_bytes_: 13793886208
# 2022-01-17 18:22:53.491479: I tensorflow/core/common_runtime/bfc_allocator.cc:1089] Stats:
# Limit:                      6896943104
# InUse:                      5865181696
# MaxInUse:                   6722982400
# NumAllocs:                     4430462
# MaxAllocSize:               1379849984
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2022-01-17 18:22:53.491565: W tensorflow/core/common_runtime/bfc_allocator.cc:474] ****************__**__***************************_******************************************x*******
# 2022-01-17 18:22:53.491631: W tensorflow/core/framework/op_kernel.cc:1692] OP_REQUIRES failed at conv_grad_input_ops.cc:455 : Resource exhausted: OOM when allocating tensor with shape[32,64,224,224] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# /tmp/ipykernel_896/3086029223.py in <module>
# ----> 1 h = tools_keras.fit_phase(
#       2         model,
#       3         train_dataset,
#       4         validation_dataset,
#       5         secret_dataset,
#
# /workspace/work/signature_ai/tools_keras.py in fit_phase(model, train_dataset, validation_dataset, secret_dataset, log_folder, pred_folder, model_folder, json_folder, specs, chips_all, epochs, early_stopping_delta, patience, verbose)
#      95         )
#      96     t0 = time.time()
# ---> 97     h = model.fit(
#      98         train_dataset,
#      99         epochs=epochs,
#
# /usr/local/lib/python3.8/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1182                 _r=1):
#    1183               callbacks.on_train_batch_begin(step)
# -> 1184               tmp_logs = self.train_function(iterator)
#    1185               if data_handler.should_sync:
#    1186                 context.async_wait()
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     883
#     884       with OptionalXlaContext(self._jit_compile):
# --> 885         result = self._call(*args, **kwds)
#     886
#     887       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     948         # Lifting succeeded, so variables are initialized and we can run the
#     949         # stateless function.
# --> 950         return self._stateless_fn(*args, **kwds)
#     951     else:
#     952       _, _, _, filtered_flat_args = \
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    3037       (graph_function,
#    3038        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 3039     return graph_function._call_flat(
#    3040         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3041
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1961         and executing_eagerly):
#    1962       # No tape is watching; skip to running the function.
# -> 1963       return self._build_call_outputs(self._inference_function.call(
#    1964           ctx, args, cancellation_manager=cancellation_manager))
#    1965     forward_backward = self._select_forward_and_backward_functions(
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     589       with _InterpolateFunctionError(self):
#     590         if cancellation_manager is None:
# --> 591           outputs = execute.execute(
#     592               str(self.signature.name),
#     593               num_outputs=self._num_outputs,
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# ResourceExhaustedError:  OOM when allocating tensor with shape[25088,4096] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[node gradient_tape/vgg16_none_none_3/vgg16/fc1/MatMul_1 (defined at workspace/work/signature_ai/tools_keras.py:97) ]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#  [Op:__inference_train_function_434149]
#
# Function call stack:
# train_function
